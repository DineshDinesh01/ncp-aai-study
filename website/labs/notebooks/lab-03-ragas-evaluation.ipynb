# %% [markdown]
# # 🔬 Lab: Agent Evaluation with RAGAS
#
# Welcome to the interactive lab for the NCP-AAI Study Guide. This notebook covers key engineering concepts tested in the certification.
#
# **Prerequisites:**
# - NVIDIA API Key (`nvapi-...`)
# - OpenAI API Key (optional, for RAGAS evaluation/tracing)

# %% [markdown]
# ### Step 1: Install RAGAS
# Evaluate Faithfulness and Context Precision for Agent RAG modules.

# %%
# !pip install -qU ragas datasets langchain-openai

# %% [markdown]
# ### Step 2: Prepare Dataset
# RAGAS evaluates tuples of (question, context, answer, ground_truth).

# %%
from datasets import Dataset

data = {
    'question': ['What is TensorRT-LLM?'],
    'answer': ['TensorRT-LLM is an NVIDIA library for optimizing large language model inference using quantization and kernel caching.'],
    'contexts': [['TensorRT-LLM provides a Python API to compile highly optimized engines for LLMs using FP8 quantization, paged KV caching, and continuous batching.']],
    'ground_truth': ['An open-source library that allows you to accelerate and optimize LLM inference on NVIDIA GPUs.']
}
dataset = Dataset.from_dict(data)
print('Dataset prepared!')

# %% [markdown]
# ### Step 3: Run RAGAS Evaluation Metrics
# We will measure 'Faithfulness' (anti-hallucination).

# %%
import os
# RAGAS requires an LLM-as-a-judge to score the metrics.
# os.environ['OPENAI_API_KEY'] = 'sk-...'

# from ragas import evaluate
# from ragas.metrics import faithfulness, answer_relevancy

# result = evaluate(
#     dataset,
#     metrics=[faithfulness, answer_relevancy]
# )
# print(result)

print('Uncomment the block above providing your API key to run the live RAGAS evaluation pipeline against the NeMo dataset.')
